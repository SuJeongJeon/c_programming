# %% [markdown]
# <a href="https://colab.research.google.com/github/SuJeongJeon/c_programming/blob/main/Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
A = 1

# %%
a = 1
b = 1

# %%
a = b = 1

# %%
a = 1
b = a

# %%
print("print(a)")
print(a)
print("print(A)")
print(A)
# Out:
# print(a)
# 1
# print(A)
# 1

# %%
type(a)

A = 1.0
type(A)
# Out:
# float

# %%
type(a), type(A)
# Out:
# (int, float)

# %%
print(type(a))
print(type(A))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a = 4
b = 3.2
c = 2

# %%
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 7.2
# 0.7999999999999998
# 12.8
# 1.25

# %%
print(a / b)
print(a % b)
print(a // b)
# Out:
# 1.25
# 0.7999999999999998
# 1.0

# %%
print(a ** b)
# Out:
# 84.44850628946526

# %%
print(int(6.2))
print(int(-6.2))
# Out:
# 6
# -6

# %%
print(5)
print(float(5))
# Out:
# 5
# 5.0

# %%
print(abs(-6.2))
# Out:
# 6.2

# %%
print(pow(4,2))
# Out:
# 16
